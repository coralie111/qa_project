# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train = pd.read_csv('data/train.csv')

target = train.iloc[:,11:]

plt.figure(figsize=(20,20))
sns.heatmap(target.corr(),  annot=True, cmap="RdBu_r", center =0)
plt.title('targets correlation')
# Out:
# Text(0.5, 1, 'targets correlation')
